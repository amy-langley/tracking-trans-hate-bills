# %%
from bs4 import BeautifulSoup
import html
import math
import os
import pandas as pd
import requests
import socket
import time
import urllib.request

# %%
aclu_pandas = pd.read_json('aclu.json') # data from https://www.aclu.org/legislative-attacks-on-lgbtq-rights?state
WEBAPP_SHENANIGANS = ['GA', 'IN', 'ME', 'ND', 'NH', 'NJ', 'SD']

#pd.set_option('display.max_colwidth', None)
#aclu_pandas.loc[pd.json_normalize(aclu_pandas['state']).loc[lambda item: item['value'] == 'PA'].index]['link'].transform(lambda x: html.unescape(x))

# %%
def expand(short_prefix: str):
    if short_prefix.lower().startswith('h'):
        return 'house'
    if short_prefix.lower().startswith('s'):
        return 'senate'

def format_ak(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.akleg.gov/basis/Bill/Text/33?Hsid=',
        prefix,
        num.zfill(4),
        'A',
    ])])

def format_ar(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2F',
        prefix,
        num,
        '.pdf',
    ])])

def format_az(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.azleg.gov/legtext/56leg/1R/bills/',
        prefix,
        num.zfill(4),
        'P.htm',
    ])])

def format_co(frame):
    bill_name = frame['name']

    # hacky
    prefix, num = bill_name.split(' ')
    _, num = num.split('-')
    return ('pdf', [''.join([
        'https://leg.colorado.gov/sites/default/files/documents/2023A/bills/2023a_',
        num,
        '_01.pdf',
    ])])

def format_ct(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://www.cga.ct.gov/2023/TOB/',
        prefix[0],
        '/PDF/2023',
        prefix,
        '-',
        num.zfill(5),
        '-R00-',
        prefix,
        '.pdf',
    ])])

def format_fl(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://www.flsenate.gov/Session/Bill/2023/',
        num,
        '/BillText/Filed/PDF',
    ])])

def format_hi(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.capitol.hawaii.gov/sessions/session2023/bills/',
        prefix,
        num,
        '_.HTM',
    ])])

def format_ia(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://www.legis.iowa.gov/docs/publications/LGI/90/',
        prefix,
        num,
        '.pdf',
    ])])

def format_id(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/',
        prefix[0],
        num.zfill(4),
        '.pdf',
    ])])

def format_ks(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'http://kslegislature.org/li/b2023_24/measures/documents/',
        prefix.lower(),
        num,
        '_00_0000.pdf',
    ])])

def format_ky(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://apps.legislature.ky.gov/recorddocuments/bill/23RS/',
        prefix.lower(),
        num,
        '/orig_bill.pdf',
    ])])

def format_md(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://mgaleg.maryland.gov/2023RS/bills/',
        prefix.lower(),
        '/',
        prefix.lower(),
        num.zfill(4),
        'F.pdf',
    ])])

def format_mi(frame):
    # TODO: hacky
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-',
        num,
        '.htm',
    ])])

def format_mn(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.revisor.mn.gov/bills/text.php?number=',
        prefix,
        num,
        '&type=bill&version=0&session=ls93&session_year=2023&session_number=0',
    ])])

def format_mo(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    
    if prefix == 'HB':
        host = 'https://www.house.mo.gov'
        page = requests.get(item['link'].replace('Bill.aspx', 'BillContent.aspx'))
        soup = BeautifulSoup(page.content)
        return ('pdf', [
            urllib.parse.urljoin(
                host, 
                soup.find_all(class_='textType')[0].find('a')['href'],
        )])

    if prefix == 'SB':
        return ('pdf', [''.join([
            'https://senate.mo.gov/23info/pdf-bill/intro/',
            prefix,
            num,
            '.pdf',
        ])])


def format_ms(frame):
    # this is such a shitty system
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    fnum = float(num)/100
    low_index = int(100*math.floor(fnum))

    # nice one, mississippi
    if low_index == 2000:
        low_index = 2001
        
    high_index = int(100*math.ceil(fnum))-1
    return ('html', [''.join([
        'http://billstatus.ls.state.ms.us/documents/2023/html/',
        prefix,
        f'/{str(low_index).zfill(4)}-{str(high_index).zfill(4)}/',
        prefix,
        num.zfill(4),
        'IN.htm',
    ])])

def format_mt(frame):
    # https://leg.mt.gov/bills/2023/billhtml/SB0099.htm
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://leg.mt.gov/bills/2023/billhtml/',
        prefix,
        num.zfill(4),
        '.htm',
    ])])

def format_nc(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://www.ncleg.gov/Sessions/2023/Bills/',
        expand(prefix),
        '/PDF/',
        prefix[0],
        num,
        'v0.pdf',
    ])])

def format_ne(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/',
        prefix,
        num,
        '.pdf',
    ])])

def format_nm(frame):
    # TODO: hacky
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.nmlegis.gov/Sessions/23%20Regular/bills/house/',
        prefix,
        num.zfill(4),
        '.html',
    ])])

def format_ok(frame):
    # TODO: this route seems busted
    # http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB789%20INT.PDF
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/',
        prefix,
        '/',
        prefix,
        num,
        '%20INT.pdf',
    ])])

def format_or(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/',
        prefix,
        num,
        '/Introduced',
    ])])

def format_pa(frame):
    # TODO: hacky
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.legis.state.pa.us/CFDOCS/Legis/PN/Public/btCheck.cfm?txtType=HTM&sessYr=2023&sessInd=0&billBody=H&billTyp=B&billNbr=',
        num.zfill(4),
        '&pn=0122',
    ])])

def format_ri(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'http://webserver.rilegislature.gov/BillText/BillText23/',
        expand(prefix).capitalize(),
        'Text23/',
        prefix[0],        num.zfill(4),
        '.pdf',
    ])])

def format_sc(frame):
    # https://www.scstatehouse.gov/sess125_2023-2024/bills/3827.htm
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://www.scstatehouse.gov/sess125_2023-2024/bills/',
        num,
        '.htm',
    ])])

def format_tn(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=',
        prefix,
        num.zfill(4),
    ])])

def format_tx(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://capitol.texas.gov/tlodocs/88R/billtext/html/',
        prefix,
        num.zfill(5),
        'I.htm',
    ])])

def format_ut(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    # haha we have to return an entire range of possible items because
    # the S03 or whatever at the end seems random nice one Utah
    return ('html', [''.join([
        'https://le.utah.gov/~2023/bills/',
        prefix.lower()[0],
        'billint/',
        prefix,
        num.zfill(4),
        'S',
        str(idx).zfill(2),
        '.htm',
    ]) for idx in range(1,9)])

def format_va(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+',
        prefix,
        num,
    ])])

def format_wa(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/',
        expand(prefix).capitalize(),
        '%20Bills/',
        num,
        '.pdf',
    ])])

def format_wv(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', [''.join([
        'http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=',
        prefix.lower(),
        num,
        '%20intr.htm&yr=2023&sesstype=RS&i=',
        num
    ])])

def format_wy(frame):
    # https://wyoleg.gov/2023/Introduced/SF0144.pdf
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', [''.join([
        'https://wyoleg.gov/2023/Introduced/',
        prefix,
        num.zfill(4),
        '.pdf',
    ])])

bill_formatters = {
    'AK': format_ak,
    'AR': format_ar,
    'AZ': format_az,
    'CO': format_co,
    'CT': format_ct,
    'FL': format_fl,
    'HI': format_hi,
    'IA': format_ia,
    'ID': format_id,
    'KS': format_ks,
    'KY': format_ky,
    'MD': format_md,
    'MI': format_mi,
    'MN': format_mn,
    'MO': format_mo,
    'MS': format_ms,
    'MT': format_mt,
    'NC': format_nc,
    'NE': format_ne,
    'NM': format_nm,
    'OK': format_ok,
    'OR': format_or,
    'PA': format_pa,
    'RI': format_ri,
    'SC': format_sc,
    'TN': format_tn,
    'TX': format_tx,
    'UT': format_ut,
    'VA': format_va,
    'WA': format_wa,
    'WV': format_wv,
    'WY': format_wy,
}

# %%
subset = aclu_pandas[['name', 'state', 'link']].copy()
subset['state'] = subset['state'].transform(lambda x: x['value'])
subset['link'] = subset['link'].transform(lambda x: html.unescape(x))

# why the fuck are LAWS using anti-scrape tech (looking at you, AZ and HI)
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# the server in WV is run by hillbillies and occasionally extremely slow for no reason
# just time out and we'll get it on a future attempt
socket.setdefaulttimeout(5)

failed = 0
skipped = 0
downloaded = 0
start = time.time()
print('Downloading legislation')

for idx, item in subset.iterrows():
    if item['state'] not in bill_formatters:
        if item['state'] not in WEBAPP_SHENANIGANS:
            print(f'I can\'t resolve {item["state"]} legislation yet')
        skipped = skipped + 1
        continue
    
    # routing for OK is fucked right now
    if item['state'] == 'OK':
        skipped = skipped + 1
        continue
    
    target_extension, URLs = bill_formatters[item['state']](item)
    
    local_name = 'bills/' + '_'.join([item['state'], item['name'].replace(' ', '_').replace('.','')])+'.' + target_extension

    if os.path.exists(local_name):
        # print(f'Skipping {item["state"]} {item["name"]}, already downloaded')
        skipped = skipped + 1
        continue
    
    for URL in URLs:
        try:
            print(f'Downloading {URL}')
            urllib.request.urlretrieve(URL, local_name)
        except Exception as e:
            failed = failed + 1
            print(f'Failed to download {URL}: {e}')
        else:
            downloaded = downloaded + 1
            break

end = time.time()
print(f'Download complete ({downloaded} downloaded, {skipped} skipped, {failed} failed)')
print(f'{end-start:.2f}s elapsed')
# Out:
# Downloading legislation
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB04129I.htm
# Downloading https://www.legis.state.pa.us/CFDOCS/Legis/PN/Public/btCheck.cfm?txtType=HTM&sessYr=2023&sessInd=0&billBody=H&billTyp=B&billNbr=0138&pn=0122
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00014I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03902I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03883I.htm
# Downloading http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-4195.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF538.pdf
# Downloading https://le.utah.gov/~2023/bills/sbillint/SB0039S01.htm
# Downloading https://www.flsenate.gov/Session/Bill/2023/1521/BillText/Filed/PDF
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF616.pdf
# Downloading https://www.flsenate.gov/Session/Bill/2023/1674/BillText/Filed/PDF
# Downloading https://www.flsenate.gov/Session/Bill/2023/1421/BillText/Filed/PDF
# Downloading https://www.flsenate.gov/Session/Bill/2023/254/BillText/Filed/PDF
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03213I.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/585.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF623.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF482.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF496.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF622.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03147I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB02862I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03164I.htm
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb228_00_0000.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF508.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/2598H.01I.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HSB208.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF482.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HSB222.pdf
# Downloading https://www.flsenate.gov/Session/Bill/2023/266/BillText/Filed/PDF
# Downloading https://www.flsenate.gov/Session/Bill/2023/999/BillText/Filed/PDF
# Downloading https://www.flsenate.gov/Session/Bill/2023/1320/BillText/Filed/PDF
# Downloading https://www.flsenate.gov/Session/Bill/2023/1223/BillText/Filed/PDF
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/2583H.02I.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HSB214.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SSB1197.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB693.pdf
# Downloading https://le.utah.gov/~2023/bills/hbillint/HB0209S01.htm
# Downloading https://www.flsenate.gov/Session/Bill/2023/1069/BillText/Filed/PDF
# Downloading https://leg.mt.gov/bills/2023/billhtml/SB0458.htm
# Downloading https://www.flsenate.gov/Session/Bill/2023/991/BillText/Filed/PDF
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB01082I.htm
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb585/orig_bill.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF348.pdf
# Downloading https://le.utah.gov/~2023/bills/hbillint/HB0463S01.htm
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1071.pdf
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB294.pdf
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb697%20intr.htm&yr=2023&sesstype=RS&i=697
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb470/orig_bill.pdf
# Downloading http://webserver.rilegislature.gov/BillText/BillText23/HouseText23/H5688.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB01029I.htm
# Downloading https://www.revisor.mn.gov/bills/text.php?number=HF1903&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# Downloading http://webserver.rilegislature.gov/BillText/BillText23/SenateText23/S0391.pdf
# Downloading https://www.nmlegis.gov/Sessions/23%20Regular/bills/house/HB0492.html
# Downloading https://leg.mt.gov/bills/2023/billhtml/SB0413.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF348.pdf
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb692%20intr.htm&yr=2023&sesstype=RS&i=692
# Failed to download http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb692%20intr.htm&yr=2023&sesstype=RS&i=692: <urlopen error timed out>
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF297.pdf
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FHB1468.pdf
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/hb2427_00_0000.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF335.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SSB1145.pdf
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3503%20intr.htm&yr=2023&sesstype=RS&i=3503
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/2490H.01I.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF290.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb145/orig_bill.pdf
# Downloading https://leg.mt.gov/bills/2023/billhtml/SB0337.htm
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb255_00_0000.pdf
# Downloading https://le.utah.gov/~2023/bills/hbillint/HB0464S01.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF325.pdf
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB270.pdf
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/H0063.pdf
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/hb2404_00_0000.pdf
# Downloading https://leg.mt.gov/bills/2023/billhtml/HB0303.htm
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb115/orig_bill.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0127H.01I.pdf
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1100.pdf
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3728.htm
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB390.pdf
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB897/Introduced
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb233_00_0000.pdf
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb224_00_0000.pdf
# Downloading http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-4075.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF229.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1411
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1117
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb150/orig_bill.pdf
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb207_00_0000.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb102/orig_bill.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1469
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1447
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb201_00_0000.pdf
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/HB2711P.htm
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb177/orig_bill.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb173/orig_bill.pdf
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb180_00_0000.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB598.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF212.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01952I.htm
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB199.pdf
# Downloading https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB810.pdf
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3801.htm
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb149_00_0000.pdf
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3304.htm
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/H0071.pdf
# Downloading https://wyoleg.gov/2023/Introduced/SF0144.pdf
# Downloading https://wyoleg.gov/2023/Introduced/SF0133.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF190.pdf
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3176%20intr.htm&yr=2023&sesstype=RS&i=3176
# Failed to download http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3176%20intr.htm&yr=2023&sesstype=RS&i=3176: <urlopen error timed out>
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3183%20intr.htm&yr=2023&sesstype=RS&i=3183
# Failed to download http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3183%20intr.htm&yr=2023&sesstype=RS&i=3183: <urlopen error timed out>
# Downloading https://www.ncleg.gov/Sessions/2023/Bills/house/PDF/H43v0.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1110
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1386
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1694P.htm
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1417P.htm
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb517%20intr.htm&yr=2023&sesstype=RS&i=517
# Downloading https://wyoleg.gov/2023/Introduced/HB0262.pdf
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3042%20intr.htm&yr=2023&sesstype=RS&i=3042
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1440
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3001%20intr.htm&yr=2023&sesstype=RS&i=3001
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1269
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF180.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1237
# Downloading https://www.revisor.mn.gov/bills/text.php?number=HF1086&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# Downloading https://www.ncleg.gov/Sessions/2023/Bills/senate/PDF/S49v0.pdf
# Downloading https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/Senate%20Bills/5653.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1414
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb2007%20intr.htm&yr=2023&sesstype=RS&i=2007
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01752I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2861IN.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01686I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2883IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1200-1299/HB1258IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1126IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2770IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2760IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1124IN.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1378
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0001
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/hb2238_00_0000.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0571
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0603
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0878
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0596
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3611.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0841
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0030
# Downloading https://www.revisor.mn.gov/bills/text.php?number=SF933&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1698P.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0466
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB125.pdf
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1480IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1476IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1489IN.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF159.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF129.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00649I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1000-1099/HB1074IN.htm
# Downloading https://mgaleg.maryland.gov/2023RS/bills/hb/hb0359F.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0620
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3827.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2764IN.htm
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1700P.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00625I.htm
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3097%20intr.htm&yr=2023&sesstype=RS&i=3097
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1702P.htm
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB42.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB2.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB48.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0501H.01I.pdf
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB791
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB29.pdf
# Downloading https://le.utah.gov/~2023/bills/hbillint/HB0132S01.htm
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0423H.01I.pdf
# Downloading https://le.utah.gov/~2023/bills/sbillint/SB0016S01.htm
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0670H.01I.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00249I.htm
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB39.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00122I.htm
# Downloading https://www.capitol.hawaii.gov/sessions/session2023/bills/SB1429_.HTM
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00041I.htm
# Downloading https://www.revisor.mn.gov/bills/text.php?number=SF724&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB165.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00250I.htm
# Downloading https://leg.colorado.gov/sites/default/files/documents/2023A/bills/2023a_1098_01.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb30/orig_bill.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00042I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01155I.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/234.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0005
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB2477/Introduced
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0414H.02I.pdf
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB960
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01541I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2820IN.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF110.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01532I.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0001
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3551.htm
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB452/Introduced
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/243.htm
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1850H.02I.pdf
# Downloading https://www.capitol.hawaii.gov/sessions/session2023/bills/HB891_.HTM
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2001-2099/SB2058IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1144IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2773IN.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0306
# Downloading https://www.capitol.hawaii.gov/sessions/session2023/bills/HB508_.HTM
# Downloading https://www.revisor.mn.gov/bills/text.php?number=HF551&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/424.htm
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB749/Introduced
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF9.pdf
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/HF8.pdf
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1040P.htm
# Downloading https://wyoleg.gov/2023/Introduced/SF0117.pdf
# Downloading https://www.capitol.hawaii.gov/sessions/session2023/bills/HB509_.HTM
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00631I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/0500-0599/HB0509IN.htm
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB1203
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1016.pdf
# Downloading https://leg.mt.gov/bills/2023/billhtml/SB0099.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/276.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2001-2099/SB2076IN.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00162I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00708I.htm
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00643I.htm
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0009
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0003
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB429.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1219H.01I.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0693H.01I.pdf
# Downloading https://leg.mt.gov/bills/2023/billhtml/HB0359.htm
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1030P.htm
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB43.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB134.pdf
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1001P.htm
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1707
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3485.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3197.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/274.htm
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB911
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB962
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1399
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00023I.htm
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB453/Introduced
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB2186/Introduced
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB87.pdf
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2765IN.htm
# Downloading https://wyoleg.gov/2023/Introduced/SF0111.pdf
# Downloading https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/House%20Bills/1223.pdf
# Downloading https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1003.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB258.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1785H.01I.pdf
# Downloading https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0239
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb253%20intr.htm&yr=2023&sesstype=RS&i=253
# Failed to download http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb253%20intr.htm&yr=2023&sesstype=RS&i=253: <urlopen error timed out>
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00476I.htm
# Downloading https://www.cga.ct.gov/2023/TOB/S/PDF/2023SB-00468-R00-SB.pdf
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB2170
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1434
# Downloading https://wyoleg.gov/2023/Introduced/HB0187.pdf
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1387
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB1186
# Downloading https://www.cga.ct.gov/2023/TOB/H/PDF/2023HB-06213-R00-HB.pdf
# Downloading https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FHB1156.pdf
# Downloading https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB3044/Introduced
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB497.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1261H.01I.pdf
# Downloading https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB2432
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00436I.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/0500-0599/HB0576IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/0400-0499/HB0456IN.htm
# Downloading https://www.legis.iowa.gov/docs/publications/LGI/90/SF83.pdf
# Downloading https://le.utah.gov/~2023/bills/sbillint/SB0100S01.htm
# Downloading https://le.utah.gov/~2023/bills/sbillint/SB0093S01.htm
# Failed to download https://le.utah.gov/~2023/bills/sbillint/SB0093S01.htm: HTTP Error 404: Not Found
# Downloading https://le.utah.gov/~2023/bills/sbillint/SB0093S02.htm
# Downloading https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB575.pdf
# Downloading https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB574.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb58/orig_bill.pdf
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/364.htm
# Downloading http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb103%20intr.htm&yr=2023&sesstype=RS&i=103
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01266I.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3616.htm
# Downloading https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB371.pdf
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1026P.htm
# Downloading https://www.azleg.gov/legtext/56leg/1R/bills/SB1028P.htm
# Downloading https://www.scstatehouse.gov/sess125_2023-2024/bills/3466.htm
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/0424H.01I.pdf
# Downloading https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00393I.htm
# Downloading https://www.akleg.gov/basis/Bill/Text/33?Hsid=HB0027A
# Downloading http://kslegislature.org/li/b2023_24/measures/documents/sb12_00_0000.pdf
# Downloading https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb120/orig_bill.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB49.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB164.pdf
# Downloading https://senate.mo.gov/23info/pdf-bill/intro/SB236.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1203H.01I.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1254H.01I.pdf
# Downloading https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/1336H.01I.pdf
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1125IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1127IN.htm
# Downloading http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2864IN.htm
# Download complete (294 downloaded, 92 skipped, 5 failed)
# 121.69s elapsed
