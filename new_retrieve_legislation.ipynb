# %%
import base64
from functools import wraps
from itertools import chain, islice
import json
import os
import pandas as pd
import requests

def legiscan_api(api_action):
    API_KEY = os.environ.get("LEGISCAN_API_KEY")
    
    @wraps(api_action)
    def api_wrapper(*args, **kwargs):
        if 'api_key' in kwargs and kwargs['api_key']:
            return api_action(*args, **kwargs)
        
        return api_action(*args, **(kwargs | {'api_key': API_KEY}))
                          
    return api_wrapper

def get_bill_meta_filename(state, bill_id):
    return f'tmp/bill_meta_{state}_{bill_id}.json'

@legiscan_api
def get_bill_meta(state, bill_id, legiscan_bill_id, api_key: str):
    local_filename = get_bill_meta_filename(state, bill_id)

    if os.path.exists(local_filename):
        #print(f'skipping {local_filename}, exists')
        return local_filename

    assembled_url = f'https://api.legiscan.com/?key={api_key}&op=getBill&id={legiscan_bill_id}'
    resp = requests.get(assembled_url)

    if not resp.ok:
        print(f'Error {resp.status_code} downloading {local_filename}')
        return None
    
    parsed = json.loads(resp.text)
    if parsed['status'].upper() == 'ERROR':
        print(f'Error {parsed["alert"]["message"]} downloading {local_filename}')
        return None
    
    with open(local_filename, 'wb') as f:
        f.write(resp.content)
    
    print(f'got {local_filename}')
    return local_filename

def get_bill_text_response_filename(state, bill_id):
    return f'tmp/bill_text_response_{state}_{bill_id}.json'

@legiscan_api
def get_bill_text(state, bill_id, legiscan_bill_id, bill_meta_path: str, api_key: str):
    local_filename = get_bill_text_response_filename(state, bill_id)

    if not bill_meta_path:
        print(f'Missing meta data {get_bill_meta_filename(state, bill_id)}')
        return None

    meta = None
    with open(bill_meta_path, 'r') as f:
        meta = json.load(f)

    texts = meta['bill']['texts']
    sorted_texts = sorted(texts, key=lambda x: x['date'], reverse=True)
    
    if len(sorted_texts) < 1:
        print(f'No bill texts available yet for {bill_meta_path}')
        return None
    
    doc_id = sorted_texts[0]['doc_id']

    if os.path.exists(local_filename):
        # print(f'skipping {local_filename}, exists')
        return local_filename

    assembled_url = f'https://api.legiscan.com/?key={api_key}&op=getBillText&id={doc_id}'
    resp = requests.get(assembled_url)

    if not resp.ok:
        print(f'Error {resp.status_code} downloading {local_filename}')
        return None
    
    parsed = json.loads(resp.text)
    if parsed['status'].upper() == 'ERROR':
        print(f'Error {parsed["alert"]["message"]} downloading {local_filename}')
        return None
    
    with open(local_filename, 'wb') as f:
        f.write(resp.content)
    
    print(f'got {local_filename}')
    return local_filename

def get_bill_contents_filename(state, bill_id, extension):
    return f'bills/{state}_{bill_id}.{extension}'

def extract_bill_contents(state, bill_id, legiscan_bill_id, _meta_path, response_path: str):
    result = None
    
    if not response_path:
        print(f'Missing response data {get_bill_text_response_filename(state, bill_id)}')
        return None
    
    with open(response_path, 'r') as f:
        result = json.load(f)['text']

    doc = result['doc']
    extension = result['mime'].split('/')[-1]
    local_filename = get_bill_contents_filename(state, bill_id, extension)

    with open(local_filename, 'wb') as f:
        f.write(base64.b64decode(doc))
    
    print(f'Created {local_filename}')
    return local_filename

# %%
def retrieve_all(filename: str):
    
    mapper = {}
    with open(filename, 'r') as f:
        mapper = json.load(f)

    tuples = chain.from_iterable(
        ((state, k, v) for k, v in m['bills'].items())
        for state, m 
        in mapper.items()
    )

    metas = [(*t, get_bill_meta(*t)) for t in tuples]
    responses = [(*meta, get_bill_text(*meta)) for meta in metas]
    extracts = [extract_bill_contents(*response) for response in responses]
    return len(extracts)

download_count = retrieve_all('resolver_map.json')
download_count
# Out:
# No bill texts available yet for tmp/bill_meta_SC_S0585.json
# Created bills/AK_HB27.pdf
# Created bills/AK_SB96.pdf
# Created bills/AK_HB105.pdf
# Created bills/AR_HB1156.pdf
# Created bills/AR_HB1468.pdf
# Created bills/AR_SB125.pdf
# Created bills/AR_SB199.pdf
# Created bills/AR_SB270.pdf
# Created bills/AR_SB43.pdf
# Created bills/AR_SB294.pdf
# Created bills/AR_HB1615.pdf
# Created bills/AZ_HB2312.html
# Created bills/AZ_HB2517.html
# Created bills/AZ_HB2711.html
# Created bills/AZ_SB1001.html
# Created bills/AZ_SB1026.html
# Created bills/AZ_SB1028.html
# Created bills/AZ_SB1030.html
# Created bills/AZ_SB1040.html
# Created bills/AZ_SB1417.html
# Created bills/AZ_SB1697.html
# Created bills/AZ_SB1698.html
# Created bills/AZ_SB1700.html
# Created bills/AZ_SB1702.html
# Created bills/AZ_SB1694.html
# Created bills/CA_AB1314.html
# Created bills/CO_HB1092.pdf
# Created bills/CO_HB1098.pdf
# Created bills/CT_HB06213.pdf
# Created bills/CT_SB00467.pdf
# Created bills/CT_SB00468.pdf
# Created bills/FL_H1421.pdf
# Created bills/FL_H1521.pdf
# Created bills/FL_S0254.html
# Created bills/FL_S1320.html
# Created bills/FL_S1674.html
# Created bills/FL_S0266.html
# Created bills/FL_H0999.pdf
# Created bills/FL_H1223.pdf
# Created bills/FL_H1069.pdf
# Created bills/FL_H0991.pdf
# Created bills/GA_HB653.pdf
# Created bills/GA_SB140.pdf
# Created bills/GA_SB141.pdf
# Created bills/GA_SB88.pdf
# Created bills/GA_SB180.pdf
# Created bills/HI_HB291.html
# Created bills/HI_HB508.html
# Created bills/HI_HB509.html
# Created bills/HI_HB891.html
# Created bills/HI_SB1428.html
# Created bills/HI_SB1429.html
# Created bills/IA_HF180.html
# Created bills/IA_HF190.html
# Created bills/IA_HF2.html
# Created bills/IA_HF482.html
# Created bills/IA_HF8.html
# Created bills/IA_SF110.html
# Created bills/IA_SF159.html
# Created bills/IA_SF335.html
# Created bills/IA_SF348.html
# Created bills/IA_SF83.html
# Created bills/IA_SSB1145.html
# Created bills/IA_SF538.html
# Created bills/IA_HF616.html
# Created bills/IA_HF623.html
# Created bills/IA_SF482.html
# Created bills/IA_SF496.html
# Created bills/IA_HF622.html
# Created bills/IA_HF508.html
# Created bills/IA_HSB208.html
# Created bills/IA_HSB222.html
# Created bills/IA_HSB214.html
# Created bills/IA_SSB1197.html
# Created bills/IA_HF348.html
# Created bills/IA_SF297.html
# Created bills/IA_HF290.html
# Created bills/IA_HF325.html
# Created bills/IA_HF229.html
# Created bills/IA_SF212.html
# Created bills/IA_SF129.html
# Created bills/ID_H0071.pdf
# Created bills/ID_S1003.pdf
# Created bills/ID_S1016.pdf
# Created bills/ID_S1100.pdf
# Created bills/ID_H0265.pdf
# Created bills/ID_S1071.pdf
# Created bills/IL_HB1071.html
# Created bills/IL_HB1562.html
# Created bills/IL_HB2184.html
# Created bills/IL_SB1659.html
# Created bills/IN_HB1118.pdf
# Created bills/IN_HB1220.pdf
# Created bills/IN_HB1231.pdf
# Created bills/IN_HB1232.pdf
# Created bills/IN_HB1346.pdf
# Created bills/IN_HB1407.pdf
# Created bills/IN_HB1503.pdf
# Created bills/IN_HB1520.pdf
# Created bills/IN_HB1525.pdf
# Created bills/IN_HB1608.pdf
# Created bills/IN_SB0351.pdf
# Created bills/IN_SB0354.pdf
# Created bills/IN_SB0386.pdf
# Created bills/IN_SB0413.pdf
# Created bills/IN_SB0480.pdf
# Created bills/IN_SB0487.pdf
# Created bills/IN_HB1524.pdf
# Created bills/IN_HB1589.pdf
# Created bills/IN_HB1569.pdf
# Created bills/KS_HB2238.pdf
# Created bills/KS_HB2303.pdf
# Created bills/KS_HB2404.pdf
# Created bills/KS_SB12.pdf
# Created bills/KS_SB149.pdf
# Created bills/KS_SB158.pdf
# Created bills/KS_SB180.pdf
# Created bills/KS_SB201.pdf
# Created bills/KS_SB207.pdf
# Created bills/KS_SB224.pdf
# Created bills/KS_SB228.pdf
# Created bills/KS_HB2427.pdf
# Created bills/KS_SB255.pdf
# Created bills/KS_SB233.pdf
# Created bills/KY_HB120.pdf
# Created bills/KY_HB173.pdf
# Created bills/KY_HB177.pdf
# Created bills/KY_HB30.pdf
# Created bills/KY_HB396.pdf
# Created bills/KY_HB470.pdf
# Created bills/KY_HB58.pdf
# Created bills/KY_HB585.pdf
# Created bills/KY_SB102.pdf
# Created bills/KY_SB115.pdf
# Created bills/KY_SB145.pdf
# Created bills/KY_SB150.pdf
# Created bills/MD_HB359.pdf
# Created bills/ME_LD123.pdf
# Created bills/ME_LD930.pdf
# Created bills/ME_LD678.pdf
# Created bills/MI_HB4195.html
# Created bills/MI_HB4257.html
# Created bills/MI_HB4075.html
# Created bills/MN_HF1086.pdf
# Created bills/MN_HF1903.pdf
# Created bills/MN_HF426.pdf
# Created bills/MN_HF551.pdf
# Created bills/MN_SF311.pdf
# Created bills/MN_SF724.pdf
# Created bills/MN_SF933.pdf
# Created bills/MN_SF934.pdf
# Created bills/MO_HB1157.pdf
# Created bills/MO_HB1258.pdf
# Created bills/MO_HB1332.pdf
# Created bills/MO_HB1333.pdf
# Created bills/MO_HB1364.pdf
# Created bills/MO_HB170.pdf
# Created bills/MO_HB183.pdf
# Created bills/MO_HB192.pdf
# Created bills/MO_HB337.pdf
# Created bills/MO_HB419.pdf
# Created bills/MO_HB463.pdf
# Created bills/MO_HB482.pdf
# Created bills/MO_HB494.pdf
# Created bills/MO_HB498.pdf
# Created bills/MO_HB540.pdf
# Created bills/MO_HB634.pdf
# Created bills/MO_HB916.pdf
# Created bills/MO_SB134.pdf
# Created bills/MO_SB164.pdf
# Created bills/MO_SB165.pdf
# Created bills/MO_SB172.pdf
# Created bills/MO_SB2.pdf
# Created bills/MO_SB236.pdf
# Created bills/MO_SB281.pdf
# Created bills/MO_SB29.pdf
# Created bills/MO_SB377.pdf
# Created bills/MO_SB39.pdf
# Created bills/MO_SB390.pdf
# Created bills/MO_SB410.pdf
# Created bills/MO_SB42.pdf
# Created bills/MO_SB429.pdf
# Created bills/MO_SB430.pdf
# Created bills/MO_SB436.pdf
# Created bills/MO_SB48.pdf
# Created bills/MO_SB49.pdf
# Created bills/MO_SB497.pdf
# Created bills/MO_SB598.pdf
# Created bills/MO_SB693.pdf
# Created bills/MO_SB87.pdf
# Created bills/MO_HB75.pdf
# Created bills/MO_SB258.pdf
# Created bills/MO_HB732.pdf
# Created bills/MO_HB489.pdf
# Created bills/MS_HB1074.html
# Created bills/MS_HB1124.html
# Created bills/MS_HB1125.html
# Created bills/MS_HB1126.html
# Created bills/MS_HB1127.html
# Created bills/MS_HB1144.html
# Created bills/MS_HB1258.html
# Created bills/MS_HB1480.html
# Created bills/MS_HB456.html
# Created bills/MS_HB576.html
# Created bills/MS_SB2076.html
# Created bills/MS_SB2760.html
# Created bills/MS_SB2763.html
# Created bills/MS_SB2764.html
# Created bills/MS_SB2770.html
# Created bills/MS_SB2773.html
# Created bills/MS_SB2820.html
# Created bills/MS_SB2861.html
# Created bills/MS_SB2864.html
# Created bills/MS_SB2883.html
# Created bills/MS_HB1476.html
# Created bills/MS_HB1489.html
# Created bills/MS_SB2058.html
# Created bills/MS_HB509.html
# Created bills/MS_SB2765.html
# Created bills/MT_HB359.pdf
# Created bills/MT_SB458.pdf
# Created bills/MT_SB99.pdf
# Created bills/MT_SB413.pdf
# Created bills/MT_SB337.pdf
# Created bills/MT_HB303.pdf
# Created bills/NC_H43.pdf
# Created bills/NC_S49.pdf
# Created bills/ND_HB1139.pdf
# Created bills/ND_HB1249.pdf
# Created bills/ND_HB1254.pdf
# Created bills/ND_HB1297.pdf
# Created bills/ND_HB1333.pdf
# Created bills/ND_HB1474.pdf
# Created bills/ND_HB1489.pdf
# Created bills/ND_HB1522.pdf
# Created bills/ND_HB1526.pdf
# Created bills/ND_HCR3010.pdf
# Created bills/ND_SB2199.pdf
# Created bills/ND_HB1111.pdf
# Created bills/ND_SB2188.pdf
# Created bills/ND_HB1488.pdf
# Created bills/ND_HB1301.pdf
# Created bills/ND_SB2231.pdf
# Created bills/ND_SB2260.pdf
# Created bills/ND_HB1205.pdf
# Created bills/ND_HB1473.pdf
# Created bills/NE_LB574.pdf
# Created bills/NE_LB575.pdf
# Created bills/NE_LB810.pdf
# Created bills/NE_LB371.pdf
# Created bills/NH_HB10.html
# Created bills/NH_HB396.html
# Created bills/NH_HB417.html
# Created bills/NH_HB619.html
# Created bills/NH_SB272.html
# Created bills/NJ_A1630.html
# Created bills/NJ_S3076.html
# Created bills/NJ_S589.html
# Created bills/NJ_A328.html
# Created bills/NJ_S585.html
# Created bills/NJ_A1418.html
# Created bills/NM_HB394.pdf
# Created bills/NM_HB492.pdf
# Created bills/NM_HM57.pdf
# Created bills/OH_HB6.pdf
# Created bills/OH_HB68.pdf
# Created bills/OK_HB1011.pdf
# Created bills/OK_HB1377.pdf
# Created bills/OK_HB1449.pdf
# Created bills/OK_HB1466.pdf
# Created bills/OK_HB2177.pdf
# Created bills/OK_HB2186.pdf
# Created bills/OK_HB2736.pdf
# Created bills/OK_SB1004.pdf
# Created bills/OK_SB1007.pdf
# Created bills/OK_SB129.pdf
# Created bills/OK_SB131.pdf
# Created bills/OK_SB250.pdf
# Created bills/OK_SB252.pdf
# Created bills/OK_SB26.pdf
# Created bills/OK_SB30.pdf
# Created bills/OK_SB345.pdf
# Created bills/OK_SB408.pdf
# Created bills/OK_SB613.pdf
# Created bills/OK_SB614.pdf
# Created bills/OK_SB731.pdf
# Created bills/OK_SB786.pdf
# Created bills/OK_SB787.pdf
# Created bills/OK_SB788.pdf
# Created bills/OK_SB789.pdf
# Created bills/OK_SB878.pdf
# Created bills/OK_SB932.pdf
# Created bills/OK_SB933.pdf
# Created bills/OK_SB937.pdf
# Created bills/OK_SB943.pdf
# Created bills/OK_SB1017.pdf
# Created bills/OK_HB1781.pdf
# Created bills/OK_HB1780.pdf
# Created bills/OK_SB973.pdf
# Created bills/OK_SB887.pdf
# Created bills/OK_SB935.pdf
# Created bills/OK_SB404.pdf
# Created bills/OR_HB2186.pdf
# Created bills/OR_HB2428.pdf
# Created bills/OR_HB2477.pdf
# Created bills/OR_HB3044.pdf
# Created bills/OR_SB246.pdf
# Created bills/OR_SB452.pdf
# Created bills/OR_SB453.pdf
# Created bills/OR_SB749.pdf
# Created bills/OR_SB897.pdf
# Created bills/PA_HB216.pdf
# Created bills/PA_HB138.pdf
# Created bills/PA_HB319.pdf
# Created bills/RI_S0391.pdf
# Created bills/RI_H5688.pdf
# Created bills/SC_H3197.html
# Created bills/SC_H3304.html
# Created bills/SC_H3485.html
# Created bills/SC_H3551.html
# Created bills/SC_H3611.html
# Created bills/SC_H3616.html
# Created bills/SC_H3728.html
# Created bills/SC_H3730.html
# Created bills/SC_H3764.html
# Created bills/SC_H3827.html
# Created bills/SC_S0234.html
# Created bills/SC_S0243.html
# Created bills/SC_S0274.html
# Created bills/SC_S0276.html
# Created bills/SC_S0364.html
# Created bills/SC_S0424.html
# Missing response data tmp/bill_text_response_SC_S0585.json
# Created bills/SC_H3801.html
# Created bills/SC_H3466.html
# Created bills/SD_HB1080.pdf
# Created bills/SD_HB1125.pdf
# Created bills/SD_HCR6008.pdf
# Created bills/SD_HB1116.pdf
# Created bills/TN_HB0001.pdf
# Created bills/TN_HB0009.pdf
# Created bills/TN_HB0030.pdf
# Created bills/TN_HB0239.pdf
# Created bills/TN_HB0306.pdf
# Created bills/TN_HB0571.pdf
# Created bills/TN_HB1215.pdf
# Created bills/TN_HB1269.pdf
# Created bills/TN_HB1378.pdf
# Created bills/TN_SB0001.pdf
# Created bills/TN_SB0003.pdf
# Created bills/TN_SB0005.pdf
# Created bills/TN_SB0466.pdf
# Created bills/TN_SB0603.pdf
# Created bills/TN_SB0841.pdf
# Created bills/TN_SB1237.pdf
# Created bills/TN_SB1339.pdf
# Created bills/TN_SB1440.pdf
# Created bills/TN_HB1411.pdf
# Created bills/TN_SB1117.pdf
# Created bills/TN_SB1469.pdf
# Created bills/TN_HB1447.pdf
# Created bills/TN_SB1110.pdf
# Created bills/TN_HB1386.pdf
# Created bills/TN_HB1414.pdf
# Created bills/TN_HB0878.pdf
# Created bills/TN_SB0596.pdf
# Created bills/TN_SB0620.pdf
# Created bills/TX_HB1006.html
# Created bills/TX_HB1029.html
# Created bills/TX_HB111.html
# Created bills/TX_HB1155.html
# Created bills/TX_HB122.html
# Created bills/TX_HB1266.html
# Created bills/TX_HB1532.html
# Created bills/TX_HB1541.html
# Created bills/TX_HB1686.html
# Created bills/TX_HB1752.html
# Created bills/TX_HB1952.html
# Created bills/TX_HB2116.html
# Created bills/TX_HB23.html
# Created bills/TX_HB2722.html
# Created bills/TX_HB2862.html
# Created bills/TX_HB3147.html
# Created bills/TX_HB319.html
# Created bills/TX_HB3213.html
# Created bills/TX_HB3360.html
# Created bills/TX_HB3850.html
# Created bills/TX_HB3883.html
# Created bills/TX_HB3902.html
# Created bills/TX_HB41.html
# Created bills/TX_HB4129.html
# Created bills/TX_HB42.html
# Created bills/TX_HB436.html
# Created bills/TX_HB4378.html
# Created bills/TX_HB4534.html
# Created bills/TX_HB4754.html
# Created bills/TX_HB4961.html
# Created bills/TX_HB5236.html
# Created bills/TX_HB5256.html
# Created bills/TX_HB631.html
# Created bills/TX_HB643.html
# Created bills/TX_HB672.html
# Created bills/TX_HB708.html
# Created bills/TX_HB776.html
# Created bills/TX_HB888.html
# Created bills/TX_HB976.html
# Created bills/TX_SB1007.html
# Created bills/TX_SB1029.html
# Created bills/TX_SB1082.html
# Created bills/TX_SB1198.html
# Created bills/TX_SB14.html
# Created bills/TX_SB15.html
# Created bills/TX_SB162.html
# Created bills/TX_SB1690.html
# Created bills/TX_SB2281.html
# Created bills/TX_SB249.html
# Created bills/TX_SB250.html
# Created bills/TX_SB393.html
# Created bills/TX_SB395.html
# Created bills/TX_SB437.html
# Created bills/TX_SB476.html
# Created bills/TX_SB625.html
# Created bills/TX_SB649.html
# Created bills/US_HB1064.pdf
# Created bills/US_HB216.pdf
# Created bills/US_HB429.pdf
# Created bills/US_HR115.pdf
# Created bills/US_SB187.pdf
# Created bills/US_SB435.pdf
# Created bills/US_SB457.pdf
# Created bills/US_SR53.pdf
# Created bills/UT_HB0132.pdf
# Created bills/UT_HB0209.pdf
# Created bills/UT_SB0016.pdf
# Created bills/UT_SB0039.pdf
# Created bills/UT_SB0093.pdf
# Created bills/UT_HB0463.pdf
# Created bills/UT_HB0464.pdf
# Created bills/UT_SB0100.pdf
# Created bills/UT_SB0097.pdf
# Created bills/VA_HB1387.html
# Created bills/VA_HB1399.html
# Created bills/VA_HB1707.html
# Created bills/VA_HB2432.html
# Created bills/VA_SB1186.html
# Created bills/VA_SB1203.html
# Created bills/VA_SB791.html
# Created bills/VA_SB911.html
# Created bills/VA_SB960.html
# Created bills/VA_SB962.html
# Created bills/VA_HB2170.html
# Created bills/VA_HB1434.html
# Created bills/WA_HB1214.pdf
# Created bills/WA_HB1233.pdf
# Created bills/WA_SB5653.pdf
# Created bills/WA_HB1223.pdf
# Created bills/WV_HB2007.html
# Created bills/WV_HB2919.html
# Created bills/WV_HB2972.html
# Created bills/WV_HB2998.html
# Created bills/WV_HB3001.html
# Created bills/WV_HB3097.html
# Created bills/WV_HB3176.html
# Created bills/WV_HB3183.html
# Created bills/WV_SB103.html
# Created bills/WV_SB253.html
# Created bills/WV_SB692.html
# Created bills/WV_SB697.html
# Created bills/WV_HB3503.html
# Created bills/WV_SB517.html
# Created bills/WV_HB3042.html
# Created bills/WY_HB0187.pdf
# Created bills/WY_SF0133.pdf
# Created bills/WY_SF0144.pdf
# Created bills/WY_SF0172.pdf
# Created bills/WY_HB0262.pdf
# Created bills/WY_SF0117.pdf
# Created bills/WY_SF0111.pdf
# 478
