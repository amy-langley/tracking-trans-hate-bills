# %%
import math
import pandas as pd

aclu_pandas = pd.read_json('aclu.json') # data from https://www.aclu.org/legislative-attacks-on-lgbtq-rights?state
# this bill was incorrectly attributed to NC instead of SC
aclu_pandas.loc[12]['state'] = {'value': 'SC', 'label': 'South Carolina'}


def expand(short_prefix: str):
    if short_prefix.lower().startswith('h'):
        return 'house'
    if short_prefix.lower().startswith('s'):
        return 'senate'

def format_ak(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.akleg.gov/basis/Bill/Text/33?Hsid=',
        prefix,
        num.zfill(4),
        'A',
    ]))

def format_ar(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2F',
        prefix,
        num,
        '.pdf',
    ]))

def format_az(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.azleg.gov/legtext/56leg/1R/bills/',
        prefix,
        num.zfill(4),
        'P.htm',
    ]))

def format_co(frame):
    bill_name = frame['name']

    # hacky
    prefix, num = bill_name.split(' ')
    _, num = num.split('-')
    return ('pdf', ''.join([
        'https://leg.colorado.gov/sites/default/files/documents/2023A/bills/2023a_',
        num,
        '_01.pdf',
    ]))

def format_ct(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://www.cga.ct.gov/2023/TOB/',
        prefix[0],
        '/PDF/2023',
        prefix,
        '-',
        num.zfill(5),
        '-R00-',
        prefix,
        '.pdf',
    ]))

def format_fl(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://www.flsenate.gov/Session/Bill/2023/',
        num,
        '/BillText/Filed/PDF',
    ]))

def format_hi(frame):
    bill_name = frame['name']
    # https://www.capitol.hawaii.gov/sessions/session2023/bills/SB1429_.HTM
    # https://www.capitol.hawaii.gov/sessions/session2023/bills/HB0891_.htm
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.capitol.hawaii.gov/sessions/session2023/bills/',
        prefix,
        num,
        '_.HTM',
    ]))

def format_ia(frame):
    bill_name = frame['name']
    # https://www.legis.iowa.gov/docs/publications/LGI/90/attachments/SF538.rtf
    # https://www.legis.iowa.gov/docs/publications/LGI/90/SF335.pdf
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://www.legis.iowa.gov/docs/publications/LGI/90/',
        prefix,
        num,
        '.pdf',
    ]))

def format_id(frame):
    bill_name = frame['name']
    # https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1071.pdf
    # https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/SB1071.pdf
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/',
        prefix[0],
        num.zfill(4),
        '.pdf',
    ]))

def format_ks(frame):
    bill_name = frame['name']
    # http://kslegislature.org/li/b2023_24/measures/documents/sb228_00_0000.pdf
    # http://kslegislature.org/li/b2023_24/measures/documents/SB228_00_0000.pdf
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'http://kslegislature.org/li/b2023_24/measures/documents/',
        prefix.lower(),
        num,
        '_00_0000.pdf',
    ]))

def format_ky(frame):
    bill_name = frame['name']
    # https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb585/orig_bill.pdf
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://apps.legislature.ky.gov/recorddocuments/bill/23RS/',
        prefix.lower(),
        num,
        '/orig_bill.pdf',
    ]))

def format_md(frame):
    bill_name = frame['name']
    # https://mgaleg.maryland.gov/2023RS/bills/hb/hb0359F.pdf
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://mgaleg.maryland.gov/2023RS/bills/',
        prefix.lower(),
        '/',
        prefix.lower(),
        num.zfill(4),
        'F.pdf',
    ]))

def format_mi(frame):
    # hacky
    bill_name = frame['name']
    # http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-4195.htm
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-',
        num,
        '.htm',
    ]))

def format_mn(frame):
    bill_name = frame['name']
    # https://www.revisor.mn.gov/bills/text.php?number=HF1903&type=bill&version=0&session=ls93&session_year=2023&session_number=0
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.revisor.mn.gov/bills/text.php?number=',
        prefix,
        num,
        '&type=bill&version=0&session=ls93&session_year=2023&session_number=0',
    ]))

def format_mo(frame):
    bill_name = frame['name']
    # https://www.house.mo.gov/billtracking/bills231/hlrbillspdf/2598H.01I.pdf
    # https://senate.mo.gov/23info/pdf-bill/intro/SB39.pdf
    prefix, num = bill_name.split(' ')
    
    if prefix == 'HB':
        # literally wtf
        # will have to come back with bsoup
        return ('pdf', None)

    if prefix == 'SB':
        return ('pdf', ''.join([
            'https://senate.mo.gov/23info/pdf-bill/intro/',
            prefix,
            num,
            '.pdf',
        ]))


def format_ms(frame):
    bill_name = frame['name']
    # http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2773IN.htm
    # http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2900/SB2773IN.htm
    
    # http://billstatus.ls.state.ms.us/documents/2023/html/SB/2001-2099/SB2058IN.htm
    # http://billstatus.ls.state.ms.us/documents/2023/html/SB/2000-2099/SB2058IN.htm
    
    # http://billstatus.ls.state.ms.us/documents/2023/html/HB/500-599/HB0509IN.htm
    
    
    prefix, num = bill_name.split(' ')
    fnum = float(num)/100
    low_index = int(100*math.floor(fnum))

    # nice one, mississippi
    if low_index == 2000:
        low_index = 2001
        
    high_index = int(100*math.ceil(fnum))-1
    return ('html', ''.join([
        'http://billstatus.ls.state.ms.us/documents/2023/html/',
        prefix,
        f'/{str(low_index).zfill(4)}-{str(high_index).zfill(4)}/',
        prefix,
        num.zfill(4),
        'IN.htm',
    ]))

def format_mt(frame):
    # https://leg.mt.gov/bills/2023/billhtml/SB0099.htm
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://leg.mt.gov/bills/2023/billhtml/',
        prefix,
        num.zfill(4),
        '.htm',
    ]))

def format_nc(frame):
    # https://www.ncleg.gov/Sessions/2023/Bills/Senate/PDF/S49v0.pdf
    # https://www.ncleg.gov/Sessions/2023/Bills/senate/PDF/S.49v0.pdf
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://www.ncleg.gov/Sessions/2023/Bills/',
        expand(prefix),
        '/PDF/',
        prefix[0],
        num,
        'v0.pdf',
    ]))

def format_ne(frame):
    # https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB371.pdf
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/',
        prefix,
        num,
        '.pdf',
    ]))

def format_nm(frame):
    # hacky
    # https://www.nmlegis.gov/Sessions/23%20Regular/bills/house/HB0492.html
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.nmlegis.gov/Sessions/23%20Regular/bills/house/',
        prefix,
        num.zfill(4),
        '.html',
    ]))

def format_ok(frame):
    # http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB789%20INT.PDF
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/',
        prefix,
        '/',
        prefix,
        num,
        '%20INT.pdf',
    ]))

def format_or(frame):
    # https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB897/Introduced
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/',
        prefix,
        num,
        '/Introduced',
    ]))

def format_ri(frame):
    # http://webserver.rilegislature.gov/BillText/BillText23/HouseText23/H5688.pdf
    # http://webserver.rilegislature.gov/BillText/BillText23/HouseText23/HB5688.pdf
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'http://webserver.rilegislature.gov/BillText/BillText23/',
        expand(prefix).capitalize(),
        'Text23/',
        prefix[0],        num.zfill(4),
        '.pdf',
    ]))

def format_sc(frame):
    # https://www.scstatehouse.gov/sess125_2023-2024/bills/3827.htm
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://www.scstatehouse.gov/sess125_2023-2024/bills/',
        num,
        '.htm',
    ]))

def format_tn(frame):
    # https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1414&GA=113
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=',
        prefix,
        num.zfill(4),
    ]))

def format_tx(frame):
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://capitol.texas.gov/tlodocs/88R/billtext/html/',
        prefix,
        num.zfill(5),
        'I.htm',
    ]))

def format_ut(frame):
    # https://le.utah.gov/~2023/bills/sbillint/SB0039S01.htm
    # https://le.utah.gov/~2023/bills/hbillint/HB0464S01.htm?r=196
    # TODO: how do i fix this dumb fucker
    # https://le.utah.gov/~2023/bills/sbillint/SB0093S02.htm
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://le.utah.gov/~2023/bills/',
        prefix.lower()[0],
        'billint/',
        prefix,
        num.zfill(4),
        'S01.htm',
    ]))

def format_va(frame):
    # https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1399
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+',
        prefix,
        num,
    ]))

def format_wa(frame):
    # https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/Senate%20Bills/5653.pdf?q=20230309165949
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/',
        expand(prefix).capitalize(),
        '%20Bills/',
        num,
        '.pdf',
    ]))

def format_wv(frame):
    # http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3001%20intr.htm&yr=2023&sesstype=RS&i=3001
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('html', ''.join([
        'http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=',
        prefix.lower(),
        num,
        '%20intr.htm&yr=2023&sesstype=RS&i=',
        num
    ]))

def format_wy(frame):
    # https://wyoleg.gov/2023/Introduced/SF0144.pdf
    bill_name = frame['name']
    prefix, num = bill_name.split(' ')
    return ('pdf', ''.join([
        'https://wyoleg.gov/2023/Introduced/',
        prefix,
        num.zfill(4),
        '.pdf',
    ]))

bill_formatters = {
    'AK': format_ak,
    'AR': format_ar,
    'AZ': format_az,
    'CO': format_co,
    'CT': format_ct,
    'FL': format_fl,
    'HI': format_hi,
    'IA': format_ia,
    'ID': format_id,
    'KS': format_ks,
    'KY': format_ky,
    'MD': format_md,
    'MI': format_mi,
    'MN': format_mn,
    'MO': format_mo,
    'MS': format_ms,
    'MT': format_mt,
    'NC': format_nc,
    'NE': format_ne,
    'NM': format_nm,
    'OK': format_ok,
    'OR': format_or,
    'RI': format_ri,
    'SC': format_sc,
    'TN': format_tn,
    'TX': format_tx,
    'UT': format_ut,
    'VA': format_va,
    'WA': format_wa,
    'WV': format_wv,
    'WY': format_wy,
}

# %%
pd.set_option('display.max_colwidth', None)
subset = aclu_pandas[['name', 'state', 'link']].copy()
subset['state'] = subset['state'].transform(lambda x: x['value'])
for idx, item in subset.iterrows():
    if item['state'] not in bill_formatters:
        continue
    
    target_extension, URL = bill_formatters[item['state']](item)
    if URL is None:
        continue
        
    print(URL)
# Out:
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03902I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03883I.htm
# http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-4195.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF538.pdf
# https://le.utah.gov/~2023/bills/sbillint/SB0039S01.htm
# https://www.flsenate.gov/Session/Bill/2023/1521/BillText/Filed/PDF
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF616.pdf
# https://www.flsenate.gov/Session/Bill/2023/1674/BillText/Filed/PDF
# https://www.flsenate.gov/Session/Bill/2023/1421/BillText/Filed/PDF
# https://www.flsenate.gov/Session/Bill/2023/254/BillText/Filed/PDF
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03213I.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/585.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF623.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF482.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF496.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF622.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03147I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB02862I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB03164I.htm
# http://kslegislature.org/li/b2023_24/measures/documents/sb228_00_0000.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1449%20INT.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF508.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HSB208.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF482.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HSB222.pdf
# https://www.flsenate.gov/Session/Bill/2023/266/BillText/Filed/PDF
# https://www.flsenate.gov/Session/Bill/2023/999/BillText/Filed/PDF
# https://www.flsenate.gov/Session/Bill/2023/1320/BillText/Filed/PDF
# https://www.flsenate.gov/Session/Bill/2023/1223/BillText/Filed/PDF
# https://www.legis.iowa.gov/docs/publications/LGI/90/HSB214.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SSB1197.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB693.pdf
# https://le.utah.gov/~2023/bills/hbillint/HB0209S01.htm
# https://www.flsenate.gov/Session/Bill/2023/1069/BillText/Filed/PDF
# https://leg.mt.gov/bills/2023/billhtml/SB0458.htm
# https://www.flsenate.gov/Session/Bill/2023/991/BillText/Filed/PDF
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB01082I.htm
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb585/orig_bill.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF348.pdf
# https://le.utah.gov/~2023/bills/hbillint/HB0463S01.htm
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1071.pdf
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB294.pdf
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb697%20intr.htm&yr=2023&sesstype=RS&i=697
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb470/orig_bill.pdf
# http://webserver.rilegislature.gov/BillText/BillText23/HouseText23/H5688.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB01029I.htm
# https://www.revisor.mn.gov/bills/text.php?number=HF1903&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# http://webserver.rilegislature.gov/BillText/BillText23/SenateText23/S0391.pdf
# https://www.nmlegis.gov/Sessions/23%20Regular/bills/house/HB0492.html
# https://leg.mt.gov/bills/2023/billhtml/SB0413.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF348.pdf
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb692%20intr.htm&yr=2023&sesstype=RS&i=692
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF297.pdf
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FHB1468.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/hb2427_00_0000.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF335.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SSB1145.pdf
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3503%20intr.htm&yr=2023&sesstype=RS&i=3503
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF290.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb145/orig_bill.pdf
# https://leg.mt.gov/bills/2023/billhtml/SB0337.htm
# http://kslegislature.org/li/b2023_24/measures/documents/sb255_00_0000.pdf
# https://le.utah.gov/~2023/bills/hbillint/HB0464S01.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF325.pdf
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB270.pdf
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/H0063.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/hb2404_00_0000.pdf
# https://leg.mt.gov/bills/2023/billhtml/HB0303.htm
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb115/orig_bill.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB943%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB933%20INT.pdf
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1100.pdf
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3728.htm
# https://senate.mo.gov/23info/pdf-bill/intro/SB390.pdf
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB897/Introduced
# http://kslegislature.org/li/b2023_24/measures/documents/sb233_00_0000.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/sb224_00_0000.pdf
# http://www.legislature.mi.gov/documents/2023-2024/billintroduced/House/htm/2023-HIB-4075.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF229.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1411
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1117
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb150/orig_bill.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/sb207_00_0000.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/sb102/orig_bill.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1469
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1447
# http://kslegislature.org/li/b2023_24/measures/documents/sb201_00_0000.pdf
# https://www.azleg.gov/legtext/56leg/1R/bills/HB2711P.htm
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb177/orig_bill.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb173/orig_bill.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/sb180_00_0000.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB598.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF212.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01952I.htm
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB199.pdf
# https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB810.pdf
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3801.htm
# http://kslegislature.org/li/b2023_24/measures/documents/sb149_00_0000.pdf
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3304.htm
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/H0071.pdf
# https://wyoleg.gov/2023/Introduced/SF0144.pdf
# https://wyoleg.gov/2023/Introduced/SF0133.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF190.pdf
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3176%20intr.htm&yr=2023&sesstype=RS&i=3176
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3183%20intr.htm&yr=2023&sesstype=RS&i=3183
# https://www.ncleg.gov/Sessions/2023/Bills/house/PDF/H43v0.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1110
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1386
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1694P.htm
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1417P.htm
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb517%20intr.htm&yr=2023&sesstype=RS&i=517
# https://wyoleg.gov/2023/Introduced/HB0262.pdf
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3042%20intr.htm&yr=2023&sesstype=RS&i=3042
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1440
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3001%20intr.htm&yr=2023&sesstype=RS&i=3001
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1269
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF180.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB1237
# https://www.revisor.mn.gov/bills/text.php?number=HF1086&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# https://www.ncleg.gov/Sessions/2023/Bills/senate/PDF/S49v0.pdf
# https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/Senate%20Bills/5653.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1414
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb2007%20intr.htm&yr=2023&sesstype=RS&i=2007
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01752I.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2861IN.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01686I.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2883IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1200-1299/HB1258IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1126IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2770IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2760IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1124IN.htm
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB1378
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0001
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB1017%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1781%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1780%20INT.pdf
# http://kslegislature.org/li/b2023_24/measures/documents/hb2238_00_0000.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0571
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0603
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0878
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0596
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3611.htm
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0841
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0030
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB2736%20INT.pdf
# https://www.revisor.mn.gov/bills/text.php?number=SF933&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1698P.htm
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0466
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB125.pdf
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1480IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1476IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1400-1499/HB1489IN.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF159.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF129.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00649I.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1000-1099/HB1074IN.htm
# https://mgaleg.maryland.gov/2023RS/bills/hb/hb0359F.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0620
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3827.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2764IN.htm
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1700P.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00625I.htm
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=hb3097%20intr.htm&yr=2023&sesstype=RS&i=3097
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1702P.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB932%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB973%20INT.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB42.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB2.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB48.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB791
# https://senate.mo.gov/23info/pdf-bill/intro/SB29.pdf
# https://le.utah.gov/~2023/bills/hbillint/HB0132S01.htm
# https://le.utah.gov/~2023/bills/sbillint/SB0016S01.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00249I.htm
# https://senate.mo.gov/23info/pdf-bill/intro/SB39.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00122I.htm
# https://www.capitol.hawaii.gov/sessions/session2023/bills/SB1429_.HTM
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB26%20INT.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00041I.htm
# https://www.revisor.mn.gov/bills/text.php?number=SF724&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# https://senate.mo.gov/23info/pdf-bill/intro/SB165.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00250I.htm
# https://leg.colorado.gov/sites/default/files/documents/2023A/bills/2023a_1098_01.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb30/orig_bill.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00042I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01155I.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/234.htm
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0005
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB2477/Introduced
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB131%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB1004%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB30%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB887%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB935%20INT.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB960
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01541I.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB937%20INT.pdf
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2820IN.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF110.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01532I.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB2177%20INT.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0001
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3551.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB878%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1466%20INT.pdf
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB452/Introduced
# https://www.scstatehouse.gov/sess125_2023-2024/bills/243.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB789%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB788%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB129%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB787%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB786%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1011%20INT.pdf
# https://www.capitol.hawaii.gov/sessions/session2023/bills/HB891_.HTM
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2001-2099/SB2058IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1144IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2773IN.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB2186%20INT.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0306
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB1007%20INT.pdf
# https://www.capitol.hawaii.gov/sessions/session2023/bills/HB508_.HTM
# https://www.revisor.mn.gov/bills/text.php?number=HF551&type=bill&version=0&session=ls93&session_year=2023&session_number=0
# https://www.scstatehouse.gov/sess125_2023-2024/bills/424.htm
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB749/Introduced
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF9.pdf
# https://www.legis.iowa.gov/docs/publications/LGI/90/HF8.pdf
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1040P.htm
# https://wyoleg.gov/2023/Introduced/SF0117.pdf
# https://www.capitol.hawaii.gov/sessions/session2023/bills/HB509_.HTM
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00631I.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/0500-0599/HB0509IN.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB250%20INT.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB1203
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1016.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB345%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB252%20INT.pdf
# https://leg.mt.gov/bills/2023/billhtml/SB0099.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/276.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2001-2099/SB2076IN.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00162I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00708I.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00643I.htm
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0009
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=SB0003
# https://senate.mo.gov/23info/pdf-bill/intro/SB429.pdf
# https://leg.mt.gov/bills/2023/billhtml/HB0359.htm
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1030P.htm
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FSB43.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB134.pdf
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1001P.htm
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1707
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3485.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3197.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/274.htm
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB911
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB962
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1399
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00023I.htm
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/SB453/Introduced
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB2186/Introduced
# https://senate.mo.gov/23info/pdf-bill/intro/SB87.pdf
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2700-2799/SB2765IN.htm
# https://wyoleg.gov/2023/Introduced/SF0111.pdf
# https://lawfilesext.leg.wa.gov/biennium/2023-24/Pdf/Bills/House%20Bills/1223.pdf
# https://legislature.idaho.gov/wp-content/uploads/sessioninfo/2023/legislation/S1003.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB258.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB408%20INT.pdf
# https://wapp.capitol.tn.gov/apps/BillInfo/Default.aspx?BillNumber=HB0239
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb253%20intr.htm&yr=2023&sesstype=RS&i=253
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00476I.htm
# https://www.cga.ct.gov/2023/TOB/S/PDF/2023SB-00468-R00-SB.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB2170
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1434
# https://wyoleg.gov/2023/Introduced/HB0187.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB1387
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+SB1186
# https://www.cga.ct.gov/2023/TOB/H/PDF/2023HB-06213-R00-HB.pdf
# https://www.arkleg.state.ar.us/Bills/FTPDocument?path=%2FBills%2F2023R%2FPublic%2FHB1156.pdf
# https://olis.oregonlegislature.gov/liz/2023R1/Downloads/MeasureDocument/HB3044/Introduced
# https://senate.mo.gov/23info/pdf-bill/intro/SB497.pdf
# https://lis.virginia.gov/cgi-bin/legp604.exe?231+ful+HB2432
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00436I.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/HB/HB1377%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB613%20INT.pdf
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB614%20INT.pdf
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/0500-0599/HB0576IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/0400-0499/HB0456IN.htm
# https://www.legis.iowa.gov/docs/publications/LGI/90/SF83.pdf
# https://le.utah.gov/~2023/bills/sbillint/SB0100S01.htm
# https://le.utah.gov/~2023/bills/sbillint/SB0093S01.htm
# https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB575.pdf
# https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB574.pdf
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB00319I.htm
# http://webserver1.lsb.state.ok.us/cf_pdf/2023-24%20INT/SB/SB404%20INT.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb58/orig_bill.pdf
# https://www.scstatehouse.gov/sess125_2023-2024/bills/364.htm
# http://www.wvlegislature.gov/Bill_Status/bills_text.cfm?billdoc=sb103%20intr.htm&yr=2023&sesstype=RS&i=103
# https://capitol.texas.gov/tlodocs/88R/billtext/html/HB01266I.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3616.htm
# https://nebraskalegislature.gov/FloorDocs/108/PDF/Intro/LB371.pdf
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1026P.htm
# https://www.azleg.gov/legtext/56leg/1R/bills/SB1028P.htm
# https://www.scstatehouse.gov/sess125_2023-2024/bills/3466.htm
# https://capitol.texas.gov/tlodocs/88R/billtext/html/SB00393I.htm
# https://www.akleg.gov/basis/Bill/Text/33?Hsid=HB0027A
# http://kslegislature.org/li/b2023_24/measures/documents/sb12_00_0000.pdf
# https://apps.legislature.ky.gov/recorddocuments/bill/23RS/hb120/orig_bill.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB49.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB164.pdf
# https://senate.mo.gov/23info/pdf-bill/intro/SB236.pdf
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1125IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/HB/1100-1199/HB1127IN.htm
# http://billstatus.ls.state.ms.us/documents/2023/html/SB/2800-2899/SB2864IN.htm
